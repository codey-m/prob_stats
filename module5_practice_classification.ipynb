# %% [markdown]
# # Module 5 practice: classification accuracy
#
# Turn model scores (log-odds) into 0/1 predictions by thresholding at 0, then measure accuracy. This is the scoring step you reuse in the final project.
#
# Run the cells in order and fill in every TODO.

# %%
import numpy as np

scores = np.array([-1.2, 0.8, 2.1, -0.5, 1.5, -2.0, 0.3, 1.1])   # model log-odds
labels = np.array([0, 0, 1, 1, 1, 0, 1, 0])                      # true labels

# %% [markdown]
# ### TODO 1: threshold and score
#
# A positive score predicts class 1, otherwise class 0. Turn scores into 0/1 predictions and compute the fraction that match the labels.

# %%
# TODO 1: predictions are 1 where score > 0, else 0
preds = ...       # (scores > 0).astype(int)
accuracy = ...    # (preds == labels).mean()
print(f"predictions = {preds.tolist()}")
print(f"accuracy = {accuracy:.3f}")

# %% [markdown]
# ### Report your result
#
# Enter the accuracy in the self-check.

# %%
print("=" * 60)
print("MODULE 5 PRACTICE (classification) - REPORT VALUES")
print("=" * 60)
print(f"R1. Accuracy (3 dec): {accuracy:.3f}")
