# %% [markdown]
# # Module 5 practice: classification accuracy
#
# Turn model scores (log-odds) into class predictions, then measure accuracy. This is the scoring step you reuse in the final project.
#
# Run the cells in order and fill in every TODO.

# %%
import numpy as np

scores = np.array([-1.2, 0.8, 2.1, -0.5, 1.5, -2.0, 0.3, 1.1])   # model log-odds
labels = np.array([0, 0, 1, 1, 1, 0, 1, 0])                      # true labels

# %% [markdown]
# ### TODO 1: threshold and score
#
# Method: threshold `scores` at zero to get 0/1 predictions (a positive score predicts class 1, otherwise class 0), then set `accuracy` to the fraction of predictions that match `labels`.

# %%
# TODO 1: threshold scores at 0 into 0/1 preds; accuracy = fraction matching labels
preds = ...
accuracy = ...
print(f"predictions = {preds.tolist()}")
print(f"accuracy = {accuracy:.3f}")

# %% [markdown]
# ### Report your result
#
# Enter the accuracy in the self-check.

# %%
print("=" * 60)
print("MODULE 5 PRACTICE (classification) - REPORT VALUES")
print("=" * 60)
print(f"R1. Accuracy (3 dec): {accuracy:.3f}")
