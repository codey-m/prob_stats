# %% [markdown]
# # Module 5 practice: fit a line
#
# Fit a least-squares line to five points and read off the slope and R-squared.
#
# Run the cells in order and fill in every TODO.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5], dtype=float)
y = np.array([2, 4, 5, 4, 5], dtype=float)

# %% [markdown]
# ### TODO 1: fit the least-squares line
#
# Method: an ordinary least-squares fit of `y` on `x`. `numpy.polyfit` does a degree-1 fit in one call and returns the coefficients highest-power first, so unpack them into `slope, intercept`.

# %%
# TODO 1: degree-1 least-squares fit of y on x; unpack slope, intercept
slope, intercept = ...
print(f"slope = {slope:.3f}, intercept = {intercept:.3f}")

# %% [markdown]
# ### R-squared
#
# R-squared (computed for you below) is the fraction of the variance in `y` explained by the fitted line.

# %%
pred = slope * x + intercept
ss_res = ((y - pred) ** 2).sum()
ss_tot = ((y - y.mean()) ** 2).sum()
r2 = 1 - ss_res / ss_tot
print(f"R^2 = {r2:.3f}")

# %%
plt.figure(figsize=(6, 4))
plt.scatter(x, y, label="data")
plt.plot(x, pred, color="red", label=f"fit: y = {intercept:.2f} + {slope:.2f}x")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Least-squares fit")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Report your results
#
# Enter the slope and R-squared in the self-check.

# %%
print("=" * 60)
print("MODULE 5 PRACTICE (regression) - REPORT VALUES")
print("=" * 60)
print(f"R1. Slope (2 dec): {slope:.2f}")
print(f"R2. R^2 (2 dec):   {r2:.2f}")
