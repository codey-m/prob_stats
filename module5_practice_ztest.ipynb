# %% [markdown]
# # Module 5 practice: a z-test in code
#
# Turn the one-sample z-test into code. Method: standardize the observed mean under the null, then convert to a two-sided p-value with the normal distribution.
#
# Run the cells in order and fill in every TODO.

# %%
import numpy as np
from scipy.stats import norm

xbar = 10.1     # observed sample mean
mu0 = 10.0      # null-hypothesis mean
sigma = 0.2     # known standard deviation
n = 25          # sample size

# %% [markdown]
# ### TODO 1: the z-statistic
#
# Standardize `xbar` under the null: measure how far it sits from `mu0` in units of the standard error of the mean (built from the known `sigma` and the sample size `n`). Store the result in `z`.

# %%
# TODO 1: standardize xbar under H0, in units of the standard error (uses sigma, n)
z = ...
print(f"z = {z:.3f}")

# %% [markdown]
# ### TODO 2: the two-sided p-value
#
# Convert `z` to a two-sided p-value: the probability under the null of a statistic at least as extreme as `|z|` in either tail. Use the standard normal CDF from `scipy.stats.norm`. Store the result in `p`.

# %%
# TODO 2: two-sided p-value from |z|, using the standard normal CDF (scipy.stats.norm)
p = ...
print(f"p-value = {p:.4f}")

# %% [markdown]
# ### Report your results
#
# Enter the z-statistic and the two-sided p-value in the self-check.

# %%
print("=" * 60)
print("MODULE 5 PRACTICE (z-test) - REPORT VALUES")
print("=" * 60)
print(f"R1. z-statistic (2 dec):       {z:.2f}")
print(f"R2. Two-sided p-value (4 dec): {p:.4f}")
