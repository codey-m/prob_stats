# %% [markdown]
# # Module 5 practice: a z-test in code
#
# Turn the one-sample z-test formula into code. With known sigma, z = (xbar - mu0) / (sigma / sqrt(n)), and the two-sided p-value is 2*(1 - Phi(|z|)), where Phi is the standard normal CDF.
#
# Run the cells in order and fill in every TODO.

# %%
import numpy as np
from scipy.stats import norm

xbar = 10.1
mu0 = 10.0
sigma = 0.2
n = 25

# %% [markdown]
# ### TODO 1: the z-statistic
#
# z = (xbar - mu0) / (sigma / sqrt(n)).

# %%
# TODO 1: standardized test statistic
z = ...           # (xbar - mu0) / (sigma / np.sqrt(n))
print(f"z = {z:.3f}")

# %% [markdown]
# ### TODO 2: the two-sided p-value
#
# p = 2 * (1 - Phi(|z|)), using scipy.stats.norm.cdf for Phi.

# %%
# TODO 2: two-sided p-value using the standard normal CDF
p = ...           # 2 * (1 - norm.cdf(abs(z)))
print(f"p-value = {p:.4f}")

# %% [markdown]
# ### Report your results
#
# Enter the z-statistic and the two-sided p-value in the self-check.

# %%
print("=" * 60)
print("MODULE 5 PRACTICE (z-test) - REPORT VALUES")
print("=" * 60)
print(f"R1. z-statistic (2 dec):       {z:.2f}")
print(f"R2. Two-sided p-value (4 dec): {p:.4f}")
