# %% [markdown]
# # Module 4 practice: maximize a likelihood
#
# For exponential data with rate theta, the log-likelihood is l(theta) = n*ln(theta) - theta*sum(x). Its maximum is the closed-form estimate theta_hat = n / sum(x). You will write both and see the estimate sit at the peak of the curve.
#
# Run the cells in order and fill in every TODO.

# %%
import numpy as np
import matplotlib.pyplot as plt

DATA = np.array([2, 4, 4, 5, 5], dtype=float)
n = len(DATA)
sum_x = DATA.sum()

# %% [markdown]
# ### TODO 1: the log-likelihood
#
# Write l(theta) = n*ln(theta) - theta*sum(x).

# %%
def loglik(theta):
    # TODO 1: exponential log-likelihood at rate theta
    return ...        # n * np.log(theta) - theta * sum_x

# %% [markdown]
# ### TODO 2: the closed-form MLE
#
# The maximizer is theta_hat = n / sum(x).

# %%
# TODO 2: closed-form maximum-likelihood estimate
theta_hat = ...       # n / sum_x
print(f"theta_hat = {theta_hat:.4f}")

# %% [markdown]
# ### See the maximum
#
# Plot l(theta) and mark theta_hat at the peak.

# %%
grid = np.linspace(0.05, 0.6, 200)
plt.figure(figsize=(7, 4))
plt.plot(grid, loglik(grid), label="log-likelihood l(theta)")
plt.axvline(theta_hat, color="red", linestyle="--", label=f"theta_hat = {theta_hat:.2f}")
plt.xlabel("theta")
plt.ylabel("l(theta)")
plt.title("Log-likelihood peaks at the MLE")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Report your result
#
# Enter theta_hat in the self-check.

# %%
print("=" * 60)
print("MODULE 4 PRACTICE (MLE) - REPORT VALUES")
print("=" * 60)
print(f"R1. MLE theta_hat (2 dec): {theta_hat:.2f}")
