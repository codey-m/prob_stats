# %% [markdown]
# # Module 4 practice: maximize a likelihood
#
# For exponential data with rate theta, method: write the log-likelihood as a function of theta, then use the closed-form maximizer. You will see the estimate sit at the peak of the curve.
#
# Run the cells in order and fill in every TODO.

# %%
import numpy as np
import matplotlib.pyplot as plt

DATA = np.array([2, 4, 4, 5, 5], dtype=float)
n = len(DATA)          # sample size
sum_x = DATA.sum()     # sum of the data

# %% [markdown]
# ### TODO 1: the log-likelihood
#
# Write `loglik(theta)`, the exponential-model log-likelihood at rate `theta`, using `n` and `sum_x`. In shape it is a log term that grows with `theta` plus a term that decreases with `theta`. Return the curve's height at `theta` (do not reduce to the estimate yet).

# %%
def loglik(theta):
    # TODO 1: exponential log-likelihood at rate theta, from n and sum_x
    return ...

# %% [markdown]
# ### TODO 2: the closed-form MLE
#
# Set `theta_hat` to the `theta` that maximizes the log-likelihood. The exponential model has a closed form in terms of `n` and `sum_x` (no calculus in code), and it is the peak of the curve above.

# %%
# TODO 2: closed-form MLE for the exponential rate, from n and sum_x
theta_hat = ...
print(f"theta_hat = {theta_hat:.4f}")

# %% [markdown]
# ### See the maximum
#
# Plot the log-likelihood and mark theta_hat at the peak.

# %%
grid = np.linspace(0.05, 0.6, 200)
plt.figure(figsize=(7, 4))
plt.plot(grid, loglik(grid), label="log-likelihood l(theta)")
plt.axvline(theta_hat, color="red", linestyle="--", label=f"theta_hat = {theta_hat:.2f}")
plt.xlabel("theta")
plt.ylabel("l(theta)")
plt.title("Log-likelihood peaks at the MLE")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Report your result
#
# Enter theta_hat in the self-check.

# %%
print("=" * 60)
print("MODULE 4 PRACTICE (MLE) - REPORT VALUES")
print("=" * 60)
print(f"R1. MLE theta_hat (2 dec): {theta_hat:.2f}")
