# %% [markdown]
# # Module 3 practice: a Bayesian update in code
#
# A normal prior meets a normal observation of known variance, and the posterior is again normal. You combine them by adding precisions (precision is one over the variance) and taking a precision-weighted mean. This is the computation behind the Lec. 8 Bayesian updating interactive, and it is the engine you use in the Module 3 lab.
#
# Run the cells in order and fill in every TODO.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixed problem: a normal prior and normal observations with known variance.
PRIOR_MEAN = 0.0
PRIOR_VAR = 1.0
LIK_VAR = 4.0            # known variance of a single observation
OBS = [3.0, 5.0, 4.0, 6.0]

# %% [markdown]
# ### TODO 1: the normal-normal update
#
# Complete `update_normal_normal`. Given a prior mean and variance, one observation, and the known likelihood variance, return the posterior mean and variance.

# %%
def update_normal_normal(prior_mean, prior_var, obs, lik_var):
    """Posterior (mean, variance) after one normal observation of known variance.
    Combine by adding precisions and taking a precision-weighted mean."""
    # TODO 1: compute the posterior variance and mean.
    post_var = ...
    post_mean = ...
    return post_mean, post_var

# %% [markdown]
# ### TODO 2: sequential updates equal a batch update
#
# Start from the prior and apply `update_normal_normal` once per observation, feeding each posterior in as the next prior. Then compare against a single batch update that treats the sample mean as one observation with variance `LIK_VAR / n`. With known variance the two agree, because normal updates combine by adding precisions.

# %%
# Sequential: update once per observation.
m, v = PRIOR_MEAN, PRIOR_VAR
for x in OBS:
    # TODO 2: replace the prior with the posterior after seeing x.
    m, v = ...
seq_mean, seq_var = m, v

# Batch: the sample mean is one observation with variance LIK_VAR / n.
n = len(OBS)
xbar = np.mean(OBS)
batch_mean, batch_var = update_normal_normal(PRIOR_MEAN, PRIOR_VAR, xbar, LIK_VAR / n)

match = np.allclose([seq_mean, seq_var], [batch_mean, batch_var])
assert match, "sequential and batch posteriors differ"
print(f"sequential posterior: mean={seq_mean:.4f}, var={seq_var:.4f}")
print(f"batch posterior:      mean={batch_mean:.4f}, var={batch_var:.4f}")
print(f"sequential == batch:  {match}")

# %% [markdown]
# ### Visualize prior, likelihood, and posterior
#
# The prior, the likelihood of the mean, and the posterior are all normal densities on one axis. The posterior sits between the prior and the data, closer to whichever is more precise, and it is narrower than either.

# %%
def npdf(x, mean, var):
    return np.exp(-(x - mean) ** 2 / (2 * var)) / np.sqrt(2 * np.pi * var)

xs = np.linspace(-4, 8, 400)
lik_var_mean = LIK_VAR / n
plt.figure(figsize=(7, 4))
plt.plot(xs, npdf(xs, PRIOR_MEAN, PRIOR_VAR), label=f"prior N({PRIOR_MEAN:.0f}, {PRIOR_VAR:.0f})")
plt.plot(xs, npdf(xs, xbar, lik_var_mean), label=f"likelihood of the mean N({xbar:.2f}, {lik_var_mean:.2f})")
plt.plot(xs, npdf(xs, seq_mean, seq_var), label=f"posterior N({seq_mean:.2f}, {seq_var:.2f})")
plt.xlabel("theta")
plt.ylabel("density")
plt.title("Prior, likelihood, and posterior")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Report your results
#
# Run the cell below and enter R1 and R2 in the self-check on the course page.

# %%
print("=" * 60)
print("MODULE 3 PRACTICE - REPORT VALUES")
print("=" * 60)
print(f"R1. Posterior mean (2 dec):      {seq_mean:.2f}")
print(f"R2. Posterior variance (2 dec):  {seq_var:.2f}")
